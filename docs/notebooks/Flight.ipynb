# %% [markdown]
# # Load flight data
#
# Create `Flight` data structure for working with flight trajectories.

# %%
import numpy as np
import pandas as pd

from pycontrails import Flight
from pycontrails.datalib.ecmwf import ERA5

# %% [markdown]
# ## Create Flight instance

# %% [markdown]
# ### From Numpy Arrays

# %%
# waypoints
longitude = np.linspace(0, 50, 100)
latitude = np.linspace(0, 10, 100)
altitude = np.linspace(11000, 11500, 100)
time = pd.date_range("2022-03-01 00:00:00", "2022-03-01 02:00:00", periods=100)

fl = Flight(longitude=longitude, latitude=latitude, altitude=altitude, time=time, flight_id="my_id")
fl
# Out:
# Flight [4 keys x 100 length, 1 attributes]
# 	Keys: longitude, latitude, time, altitude
# 	Attributes:
# 	time                [2022-03-01 00:00:00, 2022-03-01 02:00:00]
# 	longitude           [0.0, 50.0]
# 	latitude            [0.0, 10.0]
# 	altitude            [11000.0, 11500.0]
# 	flight_id           my_id

# %% [markdown]
# ### From Pandas DataFrame

# %%
# Example flight
df = pd.DataFrame()
df["longitude"] = np.linspace(0, 50, 100)
df["latitude"] = np.linspace(0, 10, 100)
df["altitude"] = 11000
df["time"] = pd.date_range("2022-03-01 00:00:00", "2022-03-01 02:00:00", periods=100)
fl = Flight(data=df, flight_id="ABC")
fl
# Out:
# Flight [4 keys x 100 length, 1 attributes]
# 	Keys: longitude, latitude, altitude, time
# 	Attributes:
# 	time                [2022-03-01 00:00:00, 2022-03-01 02:00:00]
# 	longitude           [0.0, 50.0]
# 	latitude            [0.0, 10.0]
# 	altitude            [11000.0, 11000.0]
# 	flight_id           ABC

# %% [markdown]
# ### Create Flight without Waypoints

# %%
# Example flight
attrs = dict(flight_id="1234", equip="A532")
fl = Flight.create_empty(attrs=attrs)
fl
# Out:
# Flight [4 keys x 0 length, 2 attributes]
# 	Keys: longitude, latitude, time, altitude
# 	Attributes:
# 	flight_id           1234
# 	equip               A532

# %% [markdown]
# ### Create from CSV file

# %%
# load flight
df = pd.read_csv("data/flight.csv")
fl = Flight(data=df, flight_id="csv")
fl
# Out:
# Flight [4 keys x 175 length, 1 attributes]
# 	Keys: longitude, latitude, altitude, time
# 	Attributes:
# 	time                [2022-03-01 00:50:00, 2022-03-01 03:47:00]
# 	longitude           [-97.026, -77.036]
# 	latitude            [32.931, 38.854]
# 	altitude            [190.5, 11582.4]
# 	flight_id           csv

# %% [markdown]
# ## Using the Flight instance

# %% [markdown]
# The `flight.data` attribute is a dictionary with `np.ndarray` values

# %%
# waypoints
longitude = np.linspace(0, 50, 10)
latitude = np.linspace(0, 10, 10)
altitude = np.linspace(11000, 11500, 10)
time = pd.date_range("2022-03-01 00:00:00", "2022-03-01 02:00:00", periods=10)
attrs = {"flight_id": "ABC123"}
fl = Flight(longitude=longitude, latitude=latitude, altitude=altitude, time=time, attrs=attrs)

# %%
fl
# Out:
# Flight [4 keys x 50 length, 1 attributes]
# 	Keys: longitude, latitude, time, altitude
# 	Attributes:
# 	time                [2022-03-01 00:00:00, 2022-03-01 02:00:00]
# 	longitude           [0.0, 50.0]
# 	latitude            [0.0, 10.0]
# 	altitude            [11000.0, 11500.0]
# 	flight_id           ABC

# %% [markdown]
# `Flight` attributes are stored in a dictionary on the `attrs` attribute.

# %%
fl.attrs
# Out:
# {'flight_id': 'ABC123'}

# %% [markdown]
# Data can be set / get from the `Flight` like a dictionary

# %%
# get
lat = fl["latitude"]

# set
lat[5] = 20
fl["latitude"] = lat

# get updated
fl["latitude"][5]
# Out:
# np.float64(20.0)

# %% [markdown]
# The `Flight` class contains the following convenience properties

# %%
# Pressure altitude, in hPa
fl.level
# Out:
# array([226.3170091 , 224.34300442, 222.3862176 , 220.44649846,
#        218.52369813, 216.61766904, 214.7282649 , 212.85534072,
#        210.99875274, 209.15835847])

# %%
# Altitude, in ft
fl.altitude_ft
# Out:
# array([36089.23884514, 36271.5077282 , 36453.77661126, 36636.04549431,
#        36818.31437737, 37000.58326043, 37182.85214348, 37365.12102654,
#        37547.38990959, 37729.65879265])

# %%
# Values that are constant along the flight path

# set constant value along flight waypoints
fl["constant"] = np.full(shape=fl.shape, fill_value=100)

fl.constants
# Out:
# {'constant': 100, 'flight_id': 'ABC123'}

# %%
# Flight distance, in meters
fl.length
# Out:
# np.float64(7818835.115366629)

# %%
# Time start/end
print(fl.time_start)
print(fl.time_end)
# Out:
# 2022-03-01 00:00:00
# 2022-03-01 02:00:00

# %%
# Flight duration, as a pandas Timedelta
fl.duration
# Out:
# Timedelta('0 days 02:00:00')

# %%
# Max time gap between waypoints, as a pandas Timedelta
fl.max_time_gap
# Out:
# Timedelta('0 days 00:13:20')

# %%
# Max distance gap between waypoints, in meters
fl.max_distance_gap
# Out:
# np.float64(1831403.3492360476)

# %% [markdown]
# ## Intersect with Met data

# %%
# waypoints
longitude = np.linspace(0, 50, 50)
latitude = np.linspace(0, 10, 50)
altitude = np.linspace(11000, 11500, 50)
time = pd.date_range("2022-03-01 00:00:00", "2022-03-01 02:00:00", periods=50)
fl = Flight(longitude=longitude, latitude=latitude, altitude=altitude, time=time, flight_id="ABC")

# %%
# domain
time = ("2022-03-01 00:00:00", "2022-03-01 03:00:00")
variables = ["t", "q", "u", "v", "w", "ciwc", "z", "cc"]
pressure_levels = [300, 250, 200]

# get met data
era5 = ERA5(time=time, variables=variables, pressure_levels=pressure_levels)
met = era5.open_metdataset()
# Out:
# Failed to delete temp file /tmp/84114727523364b96c50ae6a40c139fe8137f9743698d421 with error [Errno 2] No such file or directory: '/tmp/84114727523364b96c50ae6a40c139fe8137f9743698d421'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/GPAT2025/pycontrails_kt/pycontrails/datalib/ecmwf/era5.py:519, in ERA5._set_cds(self)
#     518 try:
# --> 519     self.cds = cdsapi.Client(url=self.url, key=self.key)
#     520 # cdsapi throws base-level Exception
#
# File ~/miniconda3/envs/contrails/lib/python3.12/site-packages/cdsapi/api.py:281, in Client.__new__(cls, url, key, *args, **kwargs)
#     280 def __new__(cls, url=None, key=None, *args, **kwargs):
# --> 281     _, token, _ = get_url_key_verify(url, key, None)
#     282     if ":" in token:
#
# File ~/miniconda3/envs/contrails/lib/python3.12/site-packages/cdsapi/api.py:69, in get_url_key_verify(url, key, verify)
#      68 if url is None or key is None or key is None:
# ---> 69     raise Exception("Missing/incomplete configuration file: %s" % (dotrc))
#      71 # If verify is still None, then we set to default value of True
#
# Exception: Missing/incomplete configuration file: /home/ktait98/.cdsapirc
#
# The above exception was the direct cause of the following exception:
#
# CDSCredentialsNotFound                    Traceback (most recent call last)
# Cell In[19], line 8
#       6 # get met data
#       7 era5 = ERA5(time=time, variables=variables, pressure_levels=pressure_levels)
# ----> 8 met = era5.open_metdataset()
#
# File ~/GPAT2025/pycontrails_kt/pycontrails/datalib/ecmwf/era5.py:389, in ERA5.open_metdataset(self, dataset, xr_kwargs, **kwargs)
#     386     raise ValueError("Cachestore is required to download data")
#     388 # confirm files are downloaded from CDS or MARS
# --> 389 self.download(**xr_kwargs)
#     391 # ensure all files are guaranteed to be available locally here
#     392 # this would download a file from a remote (e.g. GCP) cache
#     393 disk_cachepaths = [self.cachestore.get(f) for f in self._cachepaths]
#
# File ~/GPAT2025/pycontrails_kt/pycontrails/datalib/_met_utils/metsource.py:607, in MetDataSource.download(self, **xr_kwargs)
#     603 if times_to_download := self.list_timesteps_not_cached(**xr_kwargs):
#     604     logger.debug(
#     605         "Not all files found in cachestore. Downloading times %s", times_to_download
#     606     )
# --> 607     self.download_dataset(times_to_download)
#     608 else:
#     609     logger.debug("All data files already in cache store")
#
# File ~/GPAT2025/pycontrails_kt/pycontrails/datalib/ecmwf/era5.py:364, in ERA5.download_dataset(self, times)
#     362 LOG.debug(f"Downloading ERA5 dataset for times {times}")
#     363 for times_for_day in download_times.values():
# --> 364     self._download_file(times_for_day)
#
# File ~/GPAT2025/pycontrails_kt/pycontrails/datalib/ecmwf/era5.py:492, in ERA5._download_file(self, times)
#     490 LOG.debug(f"Performing CDS request: {request} to dataset {self.dataset}")
#     491 if not hasattr(self, "cds"):
# --> 492     self._set_cds()
#     494 self.cds.retrieve(self.dataset, request, cds_temp_filename)
#     496 # open file, edit, and save for each hourly time step
#
# File ~/GPAT2025/pycontrails_kt/pycontrails/datalib/ecmwf/era5.py:522, in ERA5._set_cds(self)
#     520 # cdsapi throws base-level Exception
#     521 except Exception as err:
# --> 522     raise CDSCredentialsNotFound from err
#
# CDSCredentialsNotFound:

# %%
# interpolate to nearest grid member
fl.intersect_met(met["air_temperature"], method="nearest")

# %%
# linear interpolation
fl.intersect_met(met["air_temperature"], method="linear")

# %% [markdown]
# ## Get Lengths

# %%
# total flight length in meters
fl.length

# %%
# intersect flight with air temperature
fl["temp"] = fl.intersect_met(met["air_temperature"], method="nearest")

# get the length of the flight where ambient temperature is > 226 K
fl.length_met("temp", threshold=226)

# %% [markdown]
# ## Plot and Resample

# %%
fl.plot(kind="scatter", s=5, figsize=(10, 6))
fl.max_distance_gap

# %%
# resample with 10 minute waypoints
fl = fl.resample_and_fill("10min")

fl.plot(kind="scatter", s=5, figsize=(10, 6))
fl.max_distance_gap

# %%
# resample with 10 second waypoints
fl = fl.resample_and_fill("10s")

fl.plot(kind="scatter", s=5, figsize=(10, 6))
fl.max_distance_gap

# %% [markdown]
# ## Clean and smooth a noisy flight with gaps

# %%
df = pd.read_csv("data/flight-noisy.csv")
df["time"] = pd.to_datetime(df["time"])
f = Flight(df, drop_duplicated_times=True)
f.plot_profile();

# %%
f = f.clean_and_resample(nominal_rocd=20)
f.plot_profile();
